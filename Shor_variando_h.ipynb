# %% [markdown]
# # **Implementación del Algoritmo de Shor para resolver el caso general del DLP**
#
# ## Simulación variando las h en el primo más grande
#
# ### Rodrigo Hernández Sacristán
#
# #### Máster en Computación Cuántica, Universidad Internacional de la Rioja (UNIR)

# %%
## LIBRERÍAS NECESARIAS 

import numpy as np
import math
import matplotlib.pyplot as plt
from qiskit import QuantumCircuit, QuantumRegister, ClassicalRegister
from qiskit.circuit.library import UnitaryGate 
from qiskit.circuit.library import QFTGate
from qiskit_aer import AerSimulator
from qiskit import transpile
from qiskit.visualization import plot_histogram
from IPython.display import display
from qiskit.quantum_info import Operator
from qiskit.circuit.library import QFT
import warnings
import random
import time

# %% [markdown]
# ## FUNCIONES EXTERNAS NECESARIAS

# %%
def es_generador(g, p):
    """Verifica si g es generador de Z_p^*"""
    orden = p - 1
    elementos_vistos = set()
    for k in range(1, orden + 1):
        elementos_vistos.add(pow(g, k, p))
    return len(elementos_vistos) == orden

def residuo_centrado(z, q):
    r = z % q
    if r > q // 2:
        r -= q
    return r

def extraer_modulo_coprimo(c_prima, mod_total):
    """ Extrae el mayor divisor 'm' de mod_total tal que gcd(c_prima, m) == 1 """
    m = mod_total
    while True:
        g = math.gcd(c_prima, m)
        if g == 1:
            break
        m = m // g
    return m

def combinar_teorema_chino(X, M, a, m):
    """ Combina x ≡ X (mod M) y x ≡ a (mod m) usando el Teorema Chino del Resto """
    g = math.gcd(M, m)
    if (a - X) % g != 0:
        return None, None  # Inconsistencia por ruido de fase
    
    m_red = m // g
    M_red = M // g
    inv = pow(M_red, -1, m_red)
    diff = (a - X) // g
    k = (diff * inv) % m_red
    
    M_nuevo = (M * m) // g
    X_nuevo = (X + k * M) % M_nuevo
    return X_nuevo, M_nuevo

# %% [markdown]
# ## ORÁCULO BASADO EN PUERTAS: BEAUREGARD $O(l^4)$

# %%
"""
Oráculo cuántico para el algoritmo de Shor (logaritmo discreto) que
implementa la EXPONENCIACIÓN MODULAR mediante puertas cuánticas
(sumadores de Draper en espacio de Fourier + esquema de Beauregard),
en sustitución de la versión basada en matrices de permutación 2^l x 2^l.

    |a>|b>|0...0>  -->  |a>|b>| g^a * h^(-b) mod p >

El registro de valor (reg_C) se multiplica EN SITIO, primero por las
potencias de g (controladas por reg_A) y después por las potencias de
h^(-1) (controladas por reg_B). Las ancillas empiezan y terminan en |0>.

Coste de qubits del registro inferior (para módulo p):
    size      = ceil(log2(p))          # qubits para el valor  
    n_ancilla = size + 2               # ancillas auxiliares    
Por ejemplo, para p = 23:  size = 5,  n_ancilla = 7.

==================================================================
"""


# ------------------------------------------------------------------
# QFT sin swaps 
# ------------------------------------------------------------------
def _qft_ns_brg(n):
    qc = QuantumCircuit(n, name="QFT")
    for j in range(n - 1, -1, -1):
        qc.h(j)
        for k in range(j - 1, -1, -1):
            qc.cp(math.pi / 2 ** (j - k), k, j)
    return qc


def _angle_brg(k, b):
    """Ángulo de rotación de Draper: b*pi / 2^k."""
    return b * np.pi / (2 ** k)


# ------------------------------------------------------------------
# Sumadores en espacio de Fourier 
# ------------------------------------------------------------------
def _phi_add_brg(n, b, factor):
    """|phi(x)> -> |phi(x + factor*b)>  (sin control)."""
    qc = QuantumCircuit(n, name=f"add({b})")
    for k in range(n):
        qc.p(factor * _angle_brg(k, b), k)
    return qc


def _phi_add_c_brg(n, b, factor):
    """Sumador con 1 control."""
    ctrl = QuantumRegister(1, "c")
    reg = QuantumRegister(n, "r")
    qc = QuantumCircuit(ctrl, reg, name=f"cadd({b})")
    for k in range(n):
        qc.cp(factor * _angle_brg(k, b), ctrl[0], reg[k])
    return qc


def _phi_add_cc_brg(n, b, factor):
    """Sumador con 2 controles."""
    ctrl = QuantumRegister(2, "c")
    reg = QuantumRegister(n, "r")
    qc = QuantumCircuit(ctrl, reg, name=f"ccadd({b})")
    for k in range(n):
        qc.mcp(factor * _angle_brg(k, b), [ctrl[0], ctrl[1]], reg[k])
    return qc


# ------------------------------------------------------------------
# Sumador modular doble-controlado  (Beauregard)
#   |phi(a)>|0>_aux -> |phi((a+y) mod N)>|0>_aux
#   El registro 'reg' entra y sale en espacio de Fourier.
# ------------------------------------------------------------------
def _phi_add_mod_N_cc_brg(n, y, N):
    ctrl = QuantumRegister(2, "ctrl")
    reg = QuantumRegister(n, "a")
    aux = QuantumRegister(1, "aux")
    qc = QuantumCircuit(ctrl, reg, aux, name=f"ccADD({y})MOD({N})")

    iqft = _qft_ns_brg(n).inverse()
    qft = _qft_ns_brg(n)

    qc.append(_phi_add_cc_brg(n, y, 1).to_gate(), list(ctrl) + list(reg))
    qc.append(_phi_add_brg(n, N, -1).to_gate(), reg)
    qc.append(iqft.to_gate(), reg)
    qc.cx(reg[n - 1], aux[0])
    qc.append(qft.to_gate(), reg)
    qc.append(_phi_add_c_brg(n, N, 1).to_gate(), [aux[0]] + list(reg))
    qc.append(_phi_add_cc_brg(n, y, -1).to_gate(), list(ctrl) + list(reg))
    qc.append(iqft.to_gate(), reg)
    qc.x(reg[n - 1])
    qc.cx(reg[n - 1], aux[0])
    qc.x(reg[n - 1])
    qc.append(qft.to_gate(), reg)
    qc.append(_phi_add_cc_brg(n, y, 1).to_gate(), list(ctrl) + list(reg))
    return qc


# ------------------------------------------------------------------
# Multiplicación modular controlada (en sitio)
#   |c>|x>|0>|0> -> |c>| (x * a mod N) si c=1, si no x >|0>|0>
# ------------------------------------------------------------------
def _mult_mod_N_partial_c_brg(y, N, size_x, size_b):
    """Multiplicación-suma fuera de sitio: |c>|x>|b>|anc> -> |c>|x>|b + y*x mod N>|anc>."""
    ctrl = QuantumRegister(1, "c")
    rx = QuantumRegister(size_x, "x")
    rb = QuantumRegister(size_b, "b")
    anc = QuantumRegister(1, "anc")
    qc = QuantumCircuit(ctrl, rx, rb, anc, name=f"CMUL0({y})")

    qc.append(_qft_ns_brg(size_b).to_gate(), rb)
    for k in range(size_x):
        add = _phi_add_mod_N_cc_brg(size_b, (2 ** k * y) % N, N)
        qc.append(add.to_gate(), [ctrl[0], rx[k]] + list(rb) + [anc[0]])
    qc.append(_qft_ns_brg(size_b).inverse().to_gate(), rb)
    return qc


def _mult_mod_N_c_brg(a, N):
    """Multiplicación modular controlada EN SITIO: |c>|x>|0>|0> -> |c>| a*x mod N >|0>|0>.
    Requiere gcd(a, N) = 1 (siempre cierto aquí porque N = p es primo)."""
    size = math.ceil(math.log2(N))
    size_x = size
    size_b = size + 1

    ctrl = QuantumRegister(1, "c")
    rx = QuantumRegister(size_x, "x")
    rb = QuantumRegister(size_b, "b")
    anc = QuantumRegister(1, "anc")
    qc = QuantumCircuit(ctrl, rx, rb, anc, name=f"CMUL({a})MOD({N})")

    qc.append(_mult_mod_N_partial_c_brg(a, N, size_x, size_b).to_gate(), qc.qubits)
    for i in range(size_x):
        qc.cswap(ctrl[0], rx[i], rb[i])
    inv_a = pow(a, -1, N)
    qc.append(_mult_mod_N_partial_c_brg(inv_a, N, size_x, size_b).inverse().to_gate(), qc.qubits)
    return qc


# ------------------------------------------------------------------
# Exponenciación modular:  |x>|input> -> |x>| (valor * a^x) mod N >
#   El registro 'input' tiene 2*ceil(log2 N)+2 qubits:
#     [ valor (size) | b (size+1) | anc (1) ]
#   El valor vive en los primeros 'size' qubits de 'input'.
# ------------------------------------------------------------------
def _mod_exp_brg(n, a, N):
    size = math.ceil(math.log2(N))
    size_input = 2 * size + 2
    xr = QuantumRegister(n, "x")
    inp = QuantumRegister(size_input, "input")
    qc = QuantumCircuit(xr, inp, name=f"{a}^x mod {N}")
    for i in range(n):
        cte = pow(a, 2 ** i, N)   # constante a^(2^i) mod N para este bit del exponente
        # multiplicar por 1 es la identidad, así que nos saltamos por completo esa multiplicación controlada.
        if cte == 1:
            continue
        g = _mult_mod_N_c_brg(cte, N)
        qc.append(g.to_gate(), [xr[i]] + list(inp))
    return qc


def num_ancillas_beauregard(p):
    """Número de qubits ancilla que necesita el oráculo para el módulo p."""
    return math.ceil(math.log2(p)) + 2


def aplicar_oraculo_beauregard(g, h, p, qc, reg_A, reg_B, reg_C, reg_anc):
    """
    Implementa f(a,b) = g^a * h^(-b) mod p mediante puertas cuánticas.

        |a>|b>|1>|0...0>  -->  |a>|b>| g^a * h^(-b) mod p >|0...0>

    Parámetros
    ----------
    reg_A, reg_B : registros de exponente (l qubits cada uno).
    reg_C        : registro de VALOR (l qubits). Debe cumplir l >= ceil(log2 p).
    reg_anc      : registro ancilla NUEVO. Tamaño = num_ancillas_beauregard(p)
                   (para p=23 -> 7 qubits). Entra y sale en |0>.
    """
    l = len(reg_A)
    size = math.ceil(math.log2(p))
    assert len(reg_C) >= size, f"reg_C necesita >= {size} qubits para p={p}"
    assert len(reg_anc) == num_ancillas_beauregard(p), \
        f"reg_anc debe tener {num_ancillas_beauregard(p)} qubits para p={p}, tiene {len(reg_anc)}"

    # El 'input' que espera _mod_exp es [valor(size) | b(size+1) | anc(1)].
    # Aquí: valor = reg_C, y el resto (size+1 + 1 = size+2) son las ancillas.
    bottom = list(reg_C) + list(reg_anc)

    # Inicializamos el registro de valor a |1> (empezamos a multiplicar desde 1)
    qc.x(reg_C[0])

    h_inv = pow(h, -1, p)
    print(f"[Cuántico] Exponenciación por puertas: base g={g} (reg_A), base h^-1={h_inv} (reg_B)")

    # 1) Multiplica en sitio por g^a  (controlado por reg_A)
    qc.append(_mod_exp_brg(l, g, p).to_gate(label=f"g^a mod {p}"), list(reg_A) + bottom)

    # 2) Multiplica en sitio por (h^-1)^b = h^-b  (controlado por reg_B)
    qc.append(_mod_exp_brg(l, h_inv, p).to_gate(label=f"h^-b mod {p}"), list(reg_B) + bottom)

# %% [markdown]
# ## Reesolvemos con 16 valores de $h$ distinto el problema: encontrar $x$ tal que $2^x=h\pmod{61}$

# %%
# ==================================================================
# PARÁMETROS: g y p FIJOS, resolvemos N_PROBLEMAS logaritmos con h aleatorio
# ==================================================================
g = 2
p = 61
p_sub_1 = p - 1   # 60
q = 64            # 2^6
l = 6

NSHOTS      = 100    # shots por logaritmo (un solo job cada uno)
N_PROBLEMAS = 16     # cuántos h distintos resolver
VERBOSE     = False  # True -> imprime el detalle intento a intento (como siempre)

if es_generador(g, p):
    print(f"{g} es generador de Z_{p}^*. Resolviendo {N_PROBLEMAS} logaritmos (g y p fijos, h variable)\n")

    # 16 valores de h distintos, entre 2 y p-2 (= 59 para p=61)
    lista_h = random.sample(range(2, p - 1), N_PROBLEMAS)

    resumen = []                      # (h, x, método, lecturas, tiempo)
    t_global_ini = time.perf_counter()

    for idx, h in enumerate(lista_h, 1):
        print(f"########## Problema {idx:2d}/{N_PROBLEMAS}:  resolver  {g}^x ≡ {h} (mod {p}) ##########")
        t_ini = time.perf_counter()

        # ---- circuito (depende de h, por eso se reconstruye en cada iteración) ----
        reg_A = QuantumRegister(l, 'A')
        reg_B = QuantumRegister(l, 'B')
        reg_C = QuantumRegister(l, 'C')
        reg_anc = QuantumRegister(num_ancillas_beauregard(p), 'anc')
        cl_A = ClassicalRegister(l, 'medida_c')
        cl_B = ClassicalRegister(l, 'medida_d')

        qc = QuantumCircuit(reg_A, reg_B, reg_C, reg_anc, cl_A, cl_B)
        qc.h(reg_A); qc.h(reg_B)
        aplicar_oraculo_beauregard(g, h, p, qc, reg_A, reg_B, reg_C, reg_anc)
        qc.append(QFTGate(num_qubits=l), reg_A)
        qc.append(QFTGate(num_qubits=l), reg_B)
        qc.measure(reg_A, cl_A); qc.measure(reg_B, cl_B)

        simulador = AerSimulator()
        qc_transpilado = transpile(qc, backend=simulador)
        cuentas = simulador.run(qc_transpilado, shots=NSHOTS).result().get_counts()

        lecturas = []
        for lect, veces in cuentas.items():
            lecturas.extend([lect] * veces)
        random.shuffle(lecturas)

        # ---- RUS + CRT (idéntico al de siempre) ----
        intentos = 0
        X_acumulado, M_acumulado = 0, 1
        x_final, metodo_exito = None, ""

        for lectura in lecturas:
            intentos += 1
            bin_d, bin_c = lectura.split()
            c, d = int(bin_c, 2), int(bin_d, 2)
            c_prima = int((c * p_sub_1 - residuo_centrado(c * p_sub_1, q)) / q) % p_sub_1
            M = round(d * p_sub_1 / q) % p_sub_1
            gcd_val = math.gcd(c_prima, p_sub_1)

            if VERBOSE:
                print(f"  Intento #{intentos:2d} | (M={M:2d}, c'={c_prima:2d})")

            if gcd_val == 1:
                x_cand = (-M * pow(c_prima, -1, p_sub_1)) % p_sub_1
                if pow(g, x_cand, p) == h:
                    x_final, metodo_exito = x_cand, "DESPEJE DIRECTO"
                    break
                continue

            m_parcial = extraer_modulo_coprimo(c_prima, p_sub_1)
            if m_parcial > 1:
                a_parcial = (-M * pow(c_prima, -1, m_parcial)) % m_parcial
                X_tmp, M_tmp = combinar_teorema_chino(X_acumulado, M_acumulado, a_parcial, m_parcial)
                if X_tmp is not None and M_tmp > M_acumulado:
                    X_acumulado, M_acumulado = X_tmp, M_tmp
                    if M_acumulado == p_sub_1 and pow(g, X_acumulado, p) == h:
                        x_final, metodo_exito = X_acumulado, "CRT"
                        break

        t_iter = time.perf_counter() - t_ini

        # ---- resultado de esta iteración ----
        if x_final is not None:
            comp = pow(g, x_final, p)
            ok = "CORRECTO" if comp == h else "INCORRECTO"
            print(f"  -> x = {x_final:2d}   ({metodo_exito}, {intentos} lecturas, {t_iter:.2f} s)"
                  f"   [comprob: {g}^{x_final} ≡ {comp} (mod {p}) -> {ok}]\n")
        else:
            print(f"  -> SIN ÉXITO en {NSHOTS} shots   ({t_iter:.2f} s)\n")

        resumen.append((h, x_final, metodo_exito, intentos, t_iter))

    t_global = time.perf_counter() - t_global_ini

    # ==================================================================
    # RESUMEN FINAL con tiempos
    # ==================================================================
    print("=" * 62)
    print(f"RESUMEN DE {N_PROBLEMAS} EJECUCIONES   (g={g}, p={p})")
    print("=" * 62)
    print(f"{'h':>4} | {'x':>4} | {'método':<16} | {'lecturas':>8} | {'tiempo (s)':>10}")
    print("-" * 56)
    for h_i, x_i, met_i, it_i, t_i in resumen:
        print(f"{h_i:>4} | {str(x_i):>4} | {met_i:<16} | {it_i:>8} | {t_i:>10.2f}")
    print("-" * 56)
    tiempos = [fila[4] for fila in resumen]
    exitos = sum(1 for fila in resumen if fila[1] is not None)
    print(f"Éxitos: {exitos}/{N_PROBLEMAS}")
    print(f"Tiempo total: {t_global:.1f} s")
    print(f"Tiempo medio por logaritmo: {sum(tiempos)/len(tiempos):.2f} s")

else:
    print(f"{g} NO es generador de Z_{p}^*. Abortando programa.")
# Out:
# 2 es generador de Z_61^*. Resolviendo 16 logaritmos (g y p fijos, h variable)
#
# ########## Problema  1/16:  resolver  2^x ≡ 10 (mod 61) ##########
# [Cuántico] Exponenciación por puertas: base g=2 (reg_A), base h^-1=55 (reg_B)
#   -> x = 23   (DESPEJE DIRECTO, 2 lecturas, 656.31 s)   [comprob: 2^23 ≡ 10 (mod 61) -> CORRECTO]
#
# ########## Problema  2/16:  resolver  2^x ≡ 34 (mod 61) ##########
# [Cuántico] Exponenciación por puertas: base g=2 (reg_A), base h^-1=9 (reg_B)
#   -> x = 48   (CRT, 7 lecturas, 652.19 s)   [comprob: 2^48 ≡ 34 (mod 61) -> CORRECTO]
#
# ########## Problema  3/16:  resolver  2^x ≡ 35 (mod 61) ##########
# [Cuántico] Exponenciación por puertas: base g=2 (reg_A), base h^-1=7 (reg_B)
#   -> x = 11   (DESPEJE DIRECTO, 5 lecturas, 654.32 s)   [comprob: 2^11 ≡ 35 (mod 61) -> CORRECTO]
#
# ########## Problema  4/16:  resolver  2^x ≡ 46 (mod 61) ##########
# [Cuántico] Exponenciación por puertas: base g=2 (reg_A), base h^-1=4 (reg_B)
#   -> x = 58   (CRT, 3 lecturas, 652.23 s)   [comprob: 2^58 ≡ 46 (mod 61) -> CORRECTO]
#
# ########## Problema  5/16:  resolver  2^x ≡ 23 (mod 61) ##########
# [Cuántico] Exponenciación por puertas: base g=2 (reg_A), base h^-1=8 (reg_B)
#   -> x = 57   (CRT, 5 lecturas, 654.80 s)   [comprob: 2^57 ≡ 23 (mod 61) -> CORRECTO]
#
# ########## Problema  6/16:  resolver  2^x ≡ 4 (mod 61) ##########
# [Cuántico] Exponenciación por puertas: base g=2 (reg_A), base h^-1=46 (reg_B)
#   -> x =  2   (DESPEJE DIRECTO, 2 lecturas, 654.46 s)   [comprob: 2^2 ≡ 4 (mod 61) -> CORRECTO]
#
# ########## Problema  7/16:  resolver  2^x ≡ 27 (mod 61) ##########
# [Cuántico] Exponenciación por puertas: base g=2 (reg_A), base h^-1=52 (reg_B)
#   -> x = 18   (DESPEJE DIRECTO, 4 lecturas, 657.01 s)   [comprob: 2^18 ≡ 27 (mod 61) -> CORRECTO]
#
# ########## Problema  8/16:  resolver  2^x ≡ 45 (mod 61) ##########
# [Cuántico] Exponenciación por puertas: base g=2 (reg_A), base h^-1=19 (reg_B)
#   -> x = 34   (CRT, 2 lecturas, 652.50 s)   [comprob: 2^34 ≡ 45 (mod 61) -> CORRECTO]
#
# ########## Problema  9/16:  resolver  2^x ≡ 20 (mod 61) ##########
# [Cuántico] Exponenciación por puertas: base g=2 (reg_A), base h^-1=58 (reg_B)
#   -> x = 24   (CRT, 4 lecturas, 656.60 s)   [comprob: 2^24 ≡ 20 (mod 61) -> CORRECTO]
#
# ########## Problema 10/16:  resolver  2^x ≡ 28 (mod 61) ##########
# [Cuántico] Exponenciación por puertas: base g=2 (reg_A), base h^-1=24 (reg_B)
#   -> x = 51   (DESPEJE DIRECTO, 2 lecturas, 653.48 s)   [comprob: 2^51 ≡ 28 (mod 61) -> CORRECTO]
#
# ########## Problema 11/16:  resolver  2^x ≡ 48 (mod 61) ##########
# [Cuántico] Exponenciación por puertas: base g=2 (reg_A), base h^-1=14 (reg_B)
#   -> x = 10   (DESPEJE DIRECTO, 2 lecturas, 655.47 s)   [comprob: 2^10 ≡ 48 (mod 61) -> CORRECTO]
#
# ########## Problema 12/16:  resolver  2^x ≡ 59 (mod 61) ##########
# [Cuántico] Exponenciación por puertas: base g=2 (reg_A), base h^-1=30 (reg_B)
#   -> x = 31   (DESPEJE DIRECTO, 2 lecturas, 652.14 s)   [comprob: 2^31 ≡ 59 (mod 61) -> CORRECTO]
#
# ########## Problema 13/16:  resolver  2^x ≡ 7 (mod 61) ##########
# [Cuántico] Exponenciación por puertas: base g=2 (reg_A), base h^-1=35 (reg_B)
#   -> x = 49   (DESPEJE DIRECTO, 1 lecturas, 658.27 s)   [comprob: 2^49 ≡ 7 (mod 61) -> CORRECTO]
#
# ########## Problema 14/16:  resolver  2^x ≡ 38 (mod 61) ##########
# [Cuántico] Exponenciación por puertas: base g=2 (reg_A), base h^-1=53 (reg_B)
#   -> x = 27   (DESPEJE DIRECTO, 3 lecturas, 653.80 s)   [comprob: 2^27 ≡ 38 (mod 61) -> CORRECTO]
#
# ########## Problema 15/16:  resolver  2^x ≡ 42 (mod 61) ##########
# [Cuántico] Exponenciación por puertas: base g=2 (reg_A), base h^-1=16 (reg_B)
#   -> x = 56   (DESPEJE DIRECTO, 5 lecturas, 646.09 s)   [comprob: 2^56 ≡ 42 (mod 61) -> CORRECTO]
#
# ########## Problema 16/16:  resolver  2^x ≡ 30 (mod 61) ##########
# [Cuántico] Exponenciación por puertas: base g=2 (reg_A), base h^-1=59 (reg_B)
#   -> x = 29   (CRT, 2 lecturas, 653.73 s)   [comprob: 2^29 ≡ 30 (mod 61) -> CORRECTO]
#
# ==============================================================
# RESUMEN DE 16 EJECUCIONES   (g=2, p=61)
# ==============================================================
#    h |    x | método           | lecturas | tiempo (s)
# --------------------------------------------------------
#   10 |   23 | DESPEJE DIRECTO  |        2 |     656.31
#   34 |   48 | CRT              |        7 |     652.19
#   35 |   11 | DESPEJE DIRECTO  |        5 |     654.32
#   46 |   58 | CRT              |        3 |     652.23
#   23 |   57 | CRT              |        5 |     654.80
#    4 |    2 | DESPEJE DIRECTO  |        2 |     654.46
#   27 |   18 | DESPEJE DIRECTO  |        4 |     657.01
#   45 |   34 | CRT              |        2 |     652.50
#   20 |   24 | CRT              |        4 |     656.60
#   28 |   51 | DESPEJE DIRECTO  |        2 |     653.48
#   48 |   10 | DESPEJE DIRECTO  |        2 |     655.47
#   59 |   31 | DESPEJE DIRECTO  |        2 |     652.14
#    7 |   49 | DESPEJE DIRECTO  |        1 |     658.27
#   38 |   27 | DESPEJE DIRECTO  |        3 |     653.80
#   42 |   56 | DESPEJE DIRECTO  |        5 |     646.09
#   30 |   29 | CRT              |        2 |     653.73
# --------------------------------------------------------
# Éxitos: 16/16
# Tiempo total: 10463.4 s
# Tiempo medio por logaritmo: 653.96 s

# %% [markdown]
# ## ORÁCULO BASADO EN PUERTAS: Montgomery $O(l^3)$

# %%
"""
Oráculo cuántico para Shor-DLP con MULTIPLICACIÓN MODULAR DE MONTGOMERY

    - Exponenciación modular en  O(n^3)   
    - Número de ancillas: 2n+1     

    |a>|b>||0..0>  ->  |a>|b>| g^a * h^(-b) mod p >

Recuento de qubits (para módulo p, con n = ceil(log2 p)):
    reg_C (valor) = n           <- tu registro de valor (smallreg)
    reg_anc       = 2n + 1       <- espacio de trabajo Montgomery
Por ejemplo para p=23 (n=5): reg_anc = 11 qubits, total del oráculo = 3n + (2n+1) = 26.

La clave de Montgomery: la reducción modular extrae el bit MENOS significativo
con una sola Hadamard (en vez del bit MÁS significativo con una QFT completa
en cada suma, como en Beauregard). Eso es lo que baja el coste a O(n^3).

"""

warnings.filterwarnings("ignore", category=DeprecationWarning)


def _qft(m):
    return QFT(m, do_swaps=False).to_gate()


def _iqft(m):
    return QFT(m, do_swaps=False).inverse().to_gate()


def _angle(k, b):
    """Ángulo de Draper: b*pi / 2^k."""
    return b * np.pi / (2 ** k)


# ------------------------------------------------------------------
# Sumadores de Draper en espacio de Fourier
# ------------------------------------------------------------------
def _ccp(theta):
    """Puerta de fase doble-controlada mediante fases simples (medio ángulo)."""
    ctrl = QuantumRegister(2, "ctrl")
    q = QuantumRegister(1, "q")
    c = QuantumCircuit(ctrl, q, name="CCP")
    c.cp(theta / 2, ctrl[1], q)
    c.cx(ctrl[0], ctrl[1])
    c.cp(-theta / 2, ctrl[1], q)
    c.cx(ctrl[0], ctrl[1])
    c.cp(theta / 2, ctrl[0], q)
    return c.to_gate()


def _phi_add_cc(n, b, factor):
    """Suma doble-controlada: |phi(x)> -> |phi(x + factor*b)>."""
    ctrl = QuantumRegister(2, "c")
    reg = QuantumRegister(n, "r")
    a = QuantumCircuit(ctrl, reg, name="CCADD")
    for k in range(n):
        a.append(_ccp(factor * _angle(k, b)), list(ctrl) + [reg[k]])
    return a.to_gate()


def _phi_add_c_ignore(n, b, factor, ignorebits):
    """Suma controlada que IGNORA los 'ignorebits' bits menos significativos
    (los ya fijados en |u> durante la reducción de Montgomery)."""
    ctrl = QuantumRegister(1, "c")
    reg = QuantumRegister(n - ignorebits, "r")
    a = QuantumCircuit(ctrl, reg, name="CADDign")
    for k in range(n):
        if k < ignorebits:
            continue
        a.cp(factor * _angle(k, b), ctrl[0], reg[k - ignorebits])
    return a.to_gate()


def _phi_add_c(n, b, factor):
    return _phi_add_c_ignore(n, b, factor, 0)


# ------------------------------------------------------------------
# Multiplicación modular de Montgomery
# ------------------------------------------------------------------
def _mult_montgomery_partial_c(n, y_montg, p):
    """Multiplicación fuera de sitio + reducción de Montgomery:
    |x>|0..0> -> |x>|0>|xy mod p>|0..0>.  'y_montg' entra en forma de Montgomery (yR mod p)."""
    ctrl = QuantumRegister(1, "ctrl")
    small = QuantumRegister(n, "small")
    big = QuantumRegister(2 * n + 1, "big")
    m = QuantumCircuit(ctrl, small, big, name="MMULp")

    # (1) multiplicación por sumas repetidas en espacio de Fourier
    m.append(_qft(2 * n + 1), big)
    for i in range(n):
        s = (2 ** i * y_montg) % p
        m.append(_phi_add_cc(2 * n + 1, s, 1), [ctrl[0], small[i]] + list(big))

    # (2) reducción de Montgomery: en cada iteración se extrae el LSB con una
    #     Hadamard y se usa para controlar una resta de p; la división por 2 es
    #     implícita porque se trabaja sobre un registro cada vez más pequeño.
    for i in range(n):
        qubits = [big[i]] + list(big[i + 1:])
        m.h(big[i])
        m.append(_phi_add_c_ignore(2 * n + 1 - i, int(p), -1, 1), qubits)

    # (3) corrección de signo: extraer el bit de signo y sumar p si es negativo
    m.append(_iqft(n + 1), big[n:])
    signbit = big[-1]
    m.append(_qft(n), big[n:2 * n])
    m.append(_phi_add_c(n, p, 1), [signbit] + list(big[n:2 * n]))
    m.h(big[n]); m.cx(big[n], signbit); m.h(big[n])

    # (4) descomputación del registro u (restas con p^{-1} mod 2^{n+1})
    uncom = list(big[:n]) + [big[-1]]
    m.append(_qft(n + 1), uncom)
    pinv = pow(p, -1, 2 ** (n + 1))
    for i in range(n):
        s = ((2 ** i * y_montg % p) * pinv) % 2 ** (n + 1)
        m.append(_phi_add_cc(n + 1, s, -1), [ctrl[0], small[i]] + uncom)

    m.append(_iqft(n), big[n:2 * n])
    m.append(_iqft(n + 1), uncom)
    return m.to_gate()


def _mult_montgomery_c(n, y, p):
    """Multiplicación modular controlada EN SITIO: |c>|x>|0> -> |c>| x*y mod p >|0>.
    Dos multiplicaciones fuera de sitio (con y y con y^{-1}) más un SWAP."""
    ctrl = QuantumRegister(1, "ctrl")
    small = QuantumRegister(n, "small")
    big = QuantumRegister(2 * n + 1, "big")
    m = QuantumCircuit(ctrl, small, big, name="MMUL")

    R = 2 ** n
    y_montg = y * R % p
    m.append(_mult_montgomery_partial_c(n, y_montg, p), m.qubits)
    for i in range(n):
        m.cswap(ctrl[0], small[i], big[n + i])
    iy_montg = pow(y, -1, p) * R % p
    m.append(_mult_montgomery_partial_c(n, iy_montg, p).inverse(), m.qubits)
    return m.to_gate()


def _mod_exp_montgomery(n, a, p):
    """|x>|input> -> |x>| valor*a^x mod p >.  input = 3n+1 qubits: [valor(n) | big(2n+1)]."""
    top = QuantumRegister(n, "top")
    bot = QuantumRegister(3 * n + 1, "bot")
    c = QuantumCircuit(top, bot, name=f"{a}^x mod {p}")
    for i in range(n):
        cte = pow(a, 2 ** i, p)
        if cte == 1:          # multiplicar por 1 es la identidad -> se salta
            continue
        c.append(_mult_montgomery_c(n, cte, p), [top[i]] + list(bot))
    return c.to_gate()



def num_ancillas_montgomery(p):
    """Ancillas que necesita el oráculo Montgomery: 2n+1 (para p=23 -> 11)."""
    return 2 * math.ceil(math.log2(p)) + 1


def aplicar_oraculo_montgomery(g, h, p, qc, reg_A, reg_B, reg_C, reg_anc):
    """
    Implementa f(a,b) = g^a * h^(-b) mod p con multiplicación de Montgomery.
    """
    n = len(reg_A)
    size = math.ceil(math.log2(p))
    assert len(reg_C) >= size, f"reg_C necesita >= {size} qubits para p={p}"
    assert len(reg_anc) == num_ancillas_montgomery(p), \
        f"reg_anc debe tener {num_ancillas_montgomery(p)} qubits para p={p}, tiene {len(reg_anc)}"

    bottom = list(reg_C) + list(reg_anc)   # smallreg(n) + big(2n+1)
    qc.x(reg_C[0])                         # valor inicial |1>
    h_inv = pow(h, -1, p)
    qc.append(_mod_exp_montgomery(n, g, p),     list(reg_A) + bottom)
    qc.append(_mod_exp_montgomery(n, h_inv, p), list(reg_B) + bottom)

# %% [markdown]
# ## Reesolvemos con 16 valores de $h$ distinto el problema: encontrar $x$ tal que $3^x=h\pmod{31}$

# %%
# ==================================================================
# PARÁMETROS: g y p FIJOS, resolvemos N_PROBLEMAS logaritmos con h aleatorio
# ==================================================================
g = 3
p = 31
p_sub_1 = p - 1   # 30
q = 32            # 2^5
l = 5

NSHOTS      = 100    # shots por logaritmo (un solo job cada uno)
N_PROBLEMAS = 8      # <-- 8 valores de h distintos
VERBOSE     = False  # True -> imprime el detalle intento a intento (como siempre)

if es_generador(g, p):
    print(f"{g} es generador de Z_{p}^*. Resolviendo {N_PROBLEMAS} logaritmos (g y p fijos, h variable)\n")

    # 8 valores de h distintos, entre 2 y p-2 (= 29 para p=31)
    lista_h = random.sample(range(2, p - 1), N_PROBLEMAS)

    resumen = []                      # (h, x, método, lecturas, tiempo)
    t_global_ini = time.perf_counter()

    for idx, h in enumerate(lista_h, 1):
        print(f"########## Problema {idx:2d}/{N_PROBLEMAS}:  resolver  {g}^x ≡ {h} (mod {p}) ##########")
        t_ini = time.perf_counter()

        # ---- circuito de Montgomery (depende de h, se reconstruye en cada iteración) ----
        reg_A = QuantumRegister(l, 'A')
        reg_B = QuantumRegister(l, 'B')
        reg_C = QuantumRegister(l, 'C')
        reg_anc = QuantumRegister(num_ancillas_montgomery(p), 'anc')
        cl_A = ClassicalRegister(l, 'medida_c')
        cl_B = ClassicalRegister(l, 'medida_d')

        qc = QuantumCircuit(reg_A, reg_B, reg_C, reg_anc, cl_A, cl_B)
        qc.h(reg_A); qc.h(reg_B)
        aplicar_oraculo_montgomery(g, h, p, qc, reg_A, reg_B, reg_C, reg_anc)
        qc.append(QFTGate(num_qubits=l), reg_A)
        qc.append(QFTGate(num_qubits=l), reg_B)
        qc.measure(reg_A, cl_A); qc.measure(reg_B, cl_B)

        simulador = AerSimulator()
        qc_transpilado = transpile(qc, backend=simulador)
        cuentas = simulador.run(qc_transpilado, shots=NSHOTS).result().get_counts()

        lecturas = []
        for lect, veces in cuentas.items():
            lecturas.extend([lect] * veces)
        random.shuffle(lecturas)

        # ---- RUS + CRT (idéntico al de siempre) ----
        intentos = 0
        X_acumulado, M_acumulado = 0, 1
        x_final, metodo_exito = None, ""

        for lectura in lecturas:
            intentos += 1
            bin_d, bin_c = lectura.split()
            c, d = int(bin_c, 2), int(bin_d, 2)
            c_prima = int((c * p_sub_1 - residuo_centrado(c * p_sub_1, q)) / q) % p_sub_1
            M = round(d * p_sub_1 / q) % p_sub_1
            gcd_val = math.gcd(c_prima, p_sub_1)

            if VERBOSE:
                print(f"  Intento #{intentos:2d} | (M={M:2d}, c'={c_prima:2d})")

            if gcd_val == 1:
                x_cand = (-M * pow(c_prima, -1, p_sub_1)) % p_sub_1
                if pow(g, x_cand, p) == h:
                    x_final, metodo_exito = x_cand, "DESPEJE DIRECTO"
                    break
                continue

            m_parcial = extraer_modulo_coprimo(c_prima, p_sub_1)
            if m_parcial > 1:
                a_parcial = (-M * pow(c_prima, -1, m_parcial)) % m_parcial
                X_tmp, M_tmp = combinar_teorema_chino(X_acumulado, M_acumulado, a_parcial, m_parcial)
                if X_tmp is not None and M_tmp > M_acumulado:
                    X_acumulado, M_acumulado = X_tmp, M_tmp
                    if M_acumulado == p_sub_1 and pow(g, X_acumulado, p) == h:
                        x_final, metodo_exito = X_acumulado, "CRT"
                        break

        t_iter = time.perf_counter() - t_ini

        # ---- resultado de esta iteración ----
        if x_final is not None:
            comp = pow(g, x_final, p)
            ok = "CORRECTO" if comp == h else "INCORRECTO"
            print(f"  -> x = {x_final:2d}   ({metodo_exito}, {intentos} lecturas, {t_iter:.2f} s)"
                  f"   [comprob: {g}^{x_final} ≡ {comp} (mod {p}) -> {ok}]\n")
        else:
            print(f"  -> SIN ÉXITO en {NSHOTS} shots   ({t_iter:.2f} s)\n")

        resumen.append((h, x_final, metodo_exito, intentos, t_iter))

    t_global = time.perf_counter() - t_global_ini

    # ==================================================================
    # RESUMEN FINAL con tiempos
    # ==================================================================
    print("=" * 62)
    print(f"RESUMEN DE {N_PROBLEMAS} EJECUCIONES   (g={g}, p={p}, oráculo Montgomery)")
    print("=" * 62)
    print(f"{'h':>4} | {'x':>4} | {'método':<16} | {'lecturas':>8} | {'tiempo (s)':>10}")
    print("-" * 56)
    for h_i, x_i, met_i, it_i, t_i in resumen:
        print(f"{h_i:>4} | {str(x_i):>4} | {met_i:<16} | {it_i:>8} | {t_i:>10.2f}")
    print("-" * 56)
    tiempos = [fila[4] for fila in resumen]
    exitos = sum(1 for fila in resumen if fila[1] is not None)
    print(f"Éxitos: {exitos}/{N_PROBLEMAS}")
    print(f"Tiempo total: {t_global:.1f} s")
    print(f"Tiempo medio por logaritmo: {sum(tiempos)/len(tiempos):.2f} s")

else:
    print(f"{g} NO es generador de Z_{p}^*. Abortando programa.")
# Out:
# 3 es generador de Z_31^*. Resolviendo 8 logaritmos (g y p fijos, h variable)
#
# ########## Problema  1/8:  resolver  3^x ≡ 18 (mod 31) ##########
#   -> x = 26   (DESPEJE DIRECTO, 5 lecturas, 181.72 s)   [comprob: 3^26 ≡ 18 (mod 31) -> CORRECTO]
#
# ########## Problema  2/8:  resolver  3^x ≡ 9 (mod 31) ##########
#   -> x =  2   (DESPEJE DIRECTO, 7 lecturas, 173.18 s)   [comprob: 3^2 ≡ 9 (mod 31) -> CORRECTO]
#
# ########## Problema  3/8:  resolver  3^x ≡ 2 (mod 31) ##########
#   -> x = 24   (CRT, 2 lecturas, 166.12 s)   [comprob: 3^24 ≡ 2 (mod 31) -> CORRECTO]
#
# ########## Problema  4/8:  resolver  3^x ≡ 20 (mod 31) ##########
#   -> x =  8   (DESPEJE DIRECTO, 1 lecturas, 171.31 s)   [comprob: 3^8 ≡ 20 (mod 31) -> CORRECTO]
#
# ########## Problema  5/8:  resolver  3^x ≡ 10 (mod 31) ##########
#   -> x = 14   (DESPEJE DIRECTO, 3 lecturas, 171.17 s)   [comprob: 3^14 ≡ 10 (mod 31) -> CORRECTO]
#
# ########## Problema  6/8:  resolver  3^x ≡ 19 (mod 31) ##########
#   -> x =  4   (DESPEJE DIRECTO, 1 lecturas, 170.76 s)   [comprob: 3^4 ≡ 19 (mod 31) -> CORRECTO]
#
# ########## Problema  7/8:  resolver  3^x ≡ 6 (mod 31) ##########
#   -> x = 25   (CRT, 5 lecturas, 170.19 s)   [comprob: 3^25 ≡ 6 (mod 31) -> CORRECTO]
#
# ########## Problema  8/8:  resolver  3^x ≡ 8 (mod 31) ##########
#   -> x = 12   (DESPEJE DIRECTO, 6 lecturas, 168.78 s)   [comprob: 3^12 ≡ 8 (mod 31) -> CORRECTO]
#
# ==============================================================
# RESUMEN DE 8 EJECUCIONES   (g=3, p=31, oráculo Montgomery)
# ==============================================================
#    h |    x | método           | lecturas | tiempo (s)
# --------------------------------------------------------
#   18 |   26 | DESPEJE DIRECTO  |        5 |     181.72
#    9 |    2 | DESPEJE DIRECTO  |        7 |     173.18
#    2 |   24 | CRT              |        2 |     166.12
#   20 |    8 | DESPEJE DIRECTO  |        1 |     171.31
#   10 |   14 | DESPEJE DIRECTO  |        3 |     171.17
#   19 |    4 | DESPEJE DIRECTO  |        1 |     170.76
#    6 |   25 | CRT              |        5 |     170.19
#    8 |   12 | DESPEJE DIRECTO  |        6 |     168.78
# --------------------------------------------------------
# Éxitos: 8/8
# Tiempo total: 1373.2 s
# Tiempo medio por logaritmo: 171.65 s

# %% [markdown]
# ## Resolvemos el mismo problema que con Montgmery con Beauregard para comparar la eficiencia con Montgomery:
#
# ### Resolvemos con 8 valores de $h$ distinto el problema: encontrar $x$ tal que $3^x=h\pmod{31}$

# %%
# ==================================================================
# PARÁMETROS: g y p FIJOS, resolvemos N_PROBLEMAS logaritmos con h aleatorio
# ==================================================================
g = 3
p = 31
p_sub_1 = p - 1   # 30
q = 32            # 2^5
l = 5

NSHOTS      = 100    # shots por logaritmo (un solo job cada uno)
N_PROBLEMAS = 8      # <-- 8 valores de h distintos
VERBOSE     = False  # True -> imprime el detalle intento a intento (como siempre)

if es_generador(g, p):
    print(f"{g} es generador de Z_{p}^*. Resolviendo {N_PROBLEMAS} logaritmos (g y p fijos, h variable)\n")

    # 8 valores de h distintos, entre 2 y p-2 (= 29 para p=31)
    lista_h = random.sample(range(2, p - 1), N_PROBLEMAS)

    resumen = []                      # (h, x, método, lecturas, tiempo)
    t_global_ini = time.perf_counter()

    for idx, h in enumerate(lista_h, 1):
        print(f"########## Problema {idx:2d}/{N_PROBLEMAS}:  resolver  {g}^x ≡ {h} (mod {p}) ##########")
        t_ini = time.perf_counter()

        # ---- circuito de Montgomery (depende de h, se reconstruye en cada iteración) ----
        reg_A = QuantumRegister(l, 'A')
        reg_B = QuantumRegister(l, 'B')
        reg_C = QuantumRegister(l, 'C')
        reg_anc = QuantumRegister(num_ancillas_beauregard(p), 'anc')
        cl_A = ClassicalRegister(l, 'medida_c')
        cl_B = ClassicalRegister(l, 'medida_d')

        qc = QuantumCircuit(reg_A, reg_B, reg_C, reg_anc, cl_A, cl_B)
        qc.h(reg_A); qc.h(reg_B)
        aplicar_oraculo_beauregard(g, h, p, qc, reg_A, reg_B, reg_C, reg_anc)
        qc.append(QFTGate(num_qubits=l), reg_A)
        qc.append(QFTGate(num_qubits=l), reg_B)
        qc.measure(reg_A, cl_A); qc.measure(reg_B, cl_B)

        simulador = AerSimulator()
        qc_transpilado = transpile(qc, backend=simulador)
        cuentas = simulador.run(qc_transpilado, shots=NSHOTS).result().get_counts()

        lecturas = []
        for lect, veces in cuentas.items():
            lecturas.extend([lect] * veces)
        random.shuffle(lecturas)

        # ---- RUS + CRT (idéntico al de siempre) ----
        intentos = 0
        X_acumulado, M_acumulado = 0, 1
        x_final, metodo_exito = None, ""

        for lectura in lecturas:
            intentos += 1
            bin_d, bin_c = lectura.split()
            c, d = int(bin_c, 2), int(bin_d, 2)
            c_prima = int((c * p_sub_1 - residuo_centrado(c * p_sub_1, q)) / q) % p_sub_1
            M = round(d * p_sub_1 / q) % p_sub_1
            gcd_val = math.gcd(c_prima, p_sub_1)

            if VERBOSE:
                print(f"  Intento #{intentos:2d} | (M={M:2d}, c'={c_prima:2d})")

            if gcd_val == 1:
                x_cand = (-M * pow(c_prima, -1, p_sub_1)) % p_sub_1
                if pow(g, x_cand, p) == h:
                    x_final, metodo_exito = x_cand, "DESPEJE DIRECTO"
                    break
                continue

            m_parcial = extraer_modulo_coprimo(c_prima, p_sub_1)
            if m_parcial > 1:
                a_parcial = (-M * pow(c_prima, -1, m_parcial)) % m_parcial
                X_tmp, M_tmp = combinar_teorema_chino(X_acumulado, M_acumulado, a_parcial, m_parcial)
                if X_tmp is not None and M_tmp > M_acumulado:
                    X_acumulado, M_acumulado = X_tmp, M_tmp
                    if M_acumulado == p_sub_1 and pow(g, X_acumulado, p) == h:
                        x_final, metodo_exito = X_acumulado, "CRT"
                        break

        t_iter = time.perf_counter() - t_ini

        # ---- resultado de esta iteración ----
        if x_final is not None:
            comp = pow(g, x_final, p)
            ok = "CORRECTO" if comp == h else "INCORRECTO"
            print(f"  -> x = {x_final:2d}   ({metodo_exito}, {intentos} lecturas, {t_iter:.2f} s)"
                  f"   [comprob: {g}^{x_final} ≡ {comp} (mod {p}) -> {ok}]\n")
        else:
            print(f"  -> SIN ÉXITO en {NSHOTS} shots   ({t_iter:.2f} s)\n")

        resumen.append((h, x_final, metodo_exito, intentos, t_iter))

    t_global = time.perf_counter() - t_global_ini

    # ==================================================================
    # RESUMEN FINAL con tiempos
    # ==================================================================
    print("=" * 62)
    print(f"RESUMEN DE {N_PROBLEMAS} EJECUCIONES   (g={g}, p={p}, oráculo Beauregard)")
    print("=" * 62)
    print(f"{'h':>4} | {'x':>4} | {'método':<16} | {'lecturas':>8} | {'tiempo (s)':>10}")
    print("-" * 56)
    for h_i, x_i, met_i, it_i, t_i in resumen:
        print(f"{h_i:>4} | {str(x_i):>4} | {met_i:<16} | {it_i:>8} | {t_i:>10.2f}")
    print("-" * 56)
    tiempos = [fila[4] for fila in resumen]
    exitos = sum(1 for fila in resumen if fila[1] is not None)
    print(f"Éxitos: {exitos}/{N_PROBLEMAS}")
    print(f"Tiempo total: {t_global:.1f} s")
    print(f"Tiempo medio por logaritmo: {sum(tiempos)/len(tiempos):.2f} s")

else:
    print(f"{g} NO es generador de Z_{p}^*. Abortando programa.")
# Out:
# 3 es generador de Z_31^*. Resolviendo 8 logaritmos (g y p fijos, h variable)
#
# ########## Problema  1/8:  resolver  3^x ≡ 22 (mod 31) ##########
# [Cuántico] Exponenciación por puertas: base g=3 (reg_A), base h^-1=24 (reg_B)
#   -> x = 17   (DESPEJE DIRECTO, 2 lecturas, 28.25 s)   [comprob: 3^17 ≡ 22 (mod 31) -> CORRECTO]
#
# ########## Problema  2/8:  resolver  3^x ≡ 12 (mod 31) ##########
# [Cuántico] Exponenciación por puertas: base g=3 (reg_A), base h^-1=13 (reg_B)
#   -> x = 19   (CRT, 9 lecturas, 27.80 s)   [comprob: 3^19 ≡ 12 (mod 31) -> CORRECTO]
#
# ########## Problema  3/8:  resolver  3^x ≡ 8 (mod 31) ##########
# [Cuántico] Exponenciación por puertas: base g=3 (reg_A), base h^-1=4 (reg_B)
#   -> x = 12   (CRT, 5 lecturas, 29.14 s)   [comprob: 3^12 ≡ 8 (mod 31) -> CORRECTO]
#
# ########## Problema  4/8:  resolver  3^x ≡ 19 (mod 31) ##########
# [Cuántico] Exponenciación por puertas: base g=3 (reg_A), base h^-1=18 (reg_B)
#   -> x =  4   (DESPEJE DIRECTO, 1 lecturas, 27.79 s)   [comprob: 3^4 ≡ 19 (mod 31) -> CORRECTO]
#
# ########## Problema  5/8:  resolver  3^x ≡ 6 (mod 31) ##########
# [Cuántico] Exponenciación por puertas: base g=3 (reg_A), base h^-1=26 (reg_B)
#   -> x = 25   (DESPEJE DIRECTO, 1 lecturas, 28.49 s)   [comprob: 3^25 ≡ 6 (mod 31) -> CORRECTO]
#
# ########## Problema  6/8:  resolver  3^x ≡ 23 (mod 31) ##########
# [Cuántico] Exponenciación por puertas: base g=3 (reg_A), base h^-1=27 (reg_B)
#   -> x = 27   (DESPEJE DIRECTO, 1 lecturas, 31.82 s)   [comprob: 3^27 ≡ 23 (mod 31) -> CORRECTO]
#
# ########## Problema  7/8:  resolver  3^x ≡ 7 (mod 31) ##########
# [Cuántico] Exponenciación por puertas: base g=3 (reg_A), base h^-1=9 (reg_B)
#   -> x = 28   (CRT, 6 lecturas, 29.61 s)   [comprob: 3^28 ≡ 7 (mod 31) -> CORRECTO]
#
# ########## Problema  8/8:  resolver  3^x ≡ 4 (mod 31) ##########
# [Cuántico] Exponenciación por puertas: base g=3 (reg_A), base h^-1=8 (reg_B)
#   -> x = 18   (CRT, 5 lecturas, 29.74 s)   [comprob: 3^18 ≡ 4 (mod 31) -> CORRECTO]
#
# ==============================================================
# RESUMEN DE 8 EJECUCIONES   (g=3, p=31, oráculo Beauregard)
# ==============================================================
#    h |    x | método           | lecturas | tiempo (s)
# --------------------------------------------------------
#   22 |   17 | DESPEJE DIRECTO  |        2 |      28.25
#   12 |   19 | CRT              |        9 |      27.80
#    8 |   12 | CRT              |        5 |      29.14
#   19 |    4 | DESPEJE DIRECTO  |        1 |      27.79
#    6 |   25 | DESPEJE DIRECTO  |        1 |      28.49
#   23 |   27 | DESPEJE DIRECTO  |        1 |      31.82
#    7 |   28 | CRT              |        6 |      29.61
#    4 |   18 | CRT              |        5 |      29.74
# --------------------------------------------------------
# Éxitos: 8/8
# Tiempo total: 232.7 s
# Tiempo medio por logaritmo: 29.08 s
